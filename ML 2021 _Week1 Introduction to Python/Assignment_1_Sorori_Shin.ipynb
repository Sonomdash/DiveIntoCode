# %% [markdown]
# <h3>Sorori Shinzaemon problem<h3>
#
# Problem 1 Number of grains of rice on the 100th day

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
rice_total = 1 
list_n_grains = []
list_total_grains = []
sum = 0
for x  in range(1,101 ,1):
    list_n_grains.append(rice_total) 
    rice_total = rice_total  * 2
    sum = sum + rice_total
    list_total_grains.append(sum)
    
    
print("Number of grains of rice on the 100th day {} pieces ".format(rice_total))
print(list_n_grains)
print(grains_total , sum)
plt.figure(figsize=(10, 10))
plt.title("Number of grains of rice on the 100th day")
plt.xlabel("number of days")
plt.ylabel("the number of rice")

plt.plot(list_n_grains, markersize=15 , linewidth=3 , color = 'red')
plt.plot(list_total_grains, markersize=15 , linewidth=3 , color = 'black')
plt.show()
# Out:
# Number of grains of rice on the 100th day 1267650600228229401496703205376 pieces
# ...

# %% [markdown]
# <h3>Problem 2 Number of rice grains outside of the 100th day<h3>

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

def compute_sorori_shinzaemon(day=10):
    """
    A function that verifies the anecdote of rice by Sorori Shinzaemon. Calculate the number of rice grains per day.
    Parameteres
    --------------
    day: int
        Number of days to get rice (default : 100)
    Returns
    --------------
    list_n_grains : list
        List of the number of rice you get one day (the length of the list is equal to day)
    list_total_grains : list
        List of the total number of rice you will receive by a certain day (the length of the list will be equal to day)
    """
    # Write the code here. pass is an instruction that means do nothing.
    rice_total = 1
    
    list_total_grains = []
    
    list_n_grains = []
    sum = 0 
    for x  in range( 1 , day ,1):
        list_n_grains.append(rice_total)  

        rice_total = rice_total * 2
        
        sum = sum + rice_total
        
        list_total_grains.append(sum)
        
    pass
    return list_n_grains, list_total_grains
list_n_grains, list_total_grains = compute_sorori_shinzaemon(day=10)
plt.figure(figsize=(10, 10))
plt.title("Number of grains of rice on the 100th day")
plt.xlabel("number of days")
plt.ylabel("the number of rice")

plt.plot(list_n_grains, markersize=15 , linewidth=3 , color = 'red')
plt.plot(list_total_grains, markersize=15 , linewidth=3 , color = 'black')
plt.show()

# %% [markdown]
# <h3>Problem 3 How many people can live for how many days with the rice we get?<h3>

# %%
def number_days_live(list_total_grains ,person , eat_rice= 90):
    days = int(list_total_grains / (person * eat_rice))
    pass

    return days

days = number_days_live(65536, 100)

print("100 people can live for {} days with 65536 rice.".format(days))
# Out:
# 10 people can live for 72 days with 65536 rice.
